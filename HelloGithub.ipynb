# %%
print 'Hello Github'
# Out:
#   File "<ipython-input-1-890811edcc17>", line 1
#     print 'Hello Github'
#                        ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Hello Github')?

# %%
print ('Hello Github')
# Out:
# Hello Github
